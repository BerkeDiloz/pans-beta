# %%
import matplotlib.pyplot as plt

cities = ['Turkey', 'Spain', 'France', 'Italy']

numbers = [52, 94, 100, 140 ]



# 2. Create the bar chart
plt.figure(figsize=(12, 8))
plt.bar(categories, numbers, color= "orange")

# 3. Customize the chart
plt.title('results')
plt.xlabel('visited')
plt.ylabel('values')

# Add exact values on top of the bars
for i, value in enumerate(numbers):
    plt.text(i, value - 0.6, str(value), ha='center')

plt.show()
#color=['red', 'yellow', 'darkred','green']
